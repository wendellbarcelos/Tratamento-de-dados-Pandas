# %%
# Importando a biblioteca
import pandas as pd

# %%
# Carregando os dados de um arquivo Json, gerou uma tabela fonte com suas chaves e valores
dados_hospedagem = pd.read_json('dados_hospedagem.json')
dados_hospedagem
# Out:
#                                           info_moveis
# 0   {'avaliacao_geral': '10.0', 'experiencia_local...
# 1   {'avaliacao_geral': '10.0', 'experiencia_local...
# 2   {'avaliacao_geral': '10.0', 'experiencia_local...
# 3   {'avaliacao_geral': '10.0', 'experiencia_local...
# 4   {'avaliacao_geral': '10.0', 'experiencia_local...
# ..                                                ...
# 65  {'avaliacao_geral': 'nan', 'experiencia_local'...
# 66  {'avaliacao_geral': 'nan', 'experiencia_local'...
# 67  {'avaliacao_geral': 'nan', 'experiencia_local'...
# 68  {'avaliacao_geral': 'nan', 'experiencia_local'...
# 69  {'avaliacao_geral': 'nan', 'experiencia_local'...
#
# [70 rows x 1 columns]

# %%
# É necessário fazer a normalização desses dados para que eles gere as colunas de forma correta,
dados_hospedagem = pd.json_normalize(dados_hospedagem['info_moveis'])
dados_hospedagem.head()
# Out:
#   avaliacao_geral experiencia_local max_hospedes  \
# 0            10.0                --            1
# 1            10.0                --           10
# 2            10.0                --           11
# 3            10.0                --           12
# 4            10.0                --           14
#
#                                      descricao_local  \
# 0  [This clean and comfortable one bedroom sits r...
# 1  [Welcome to the heart of the 'Ballard Brewery ...
# 2  [New modern house built in 2013.  Spectacular ...
# 3  [Our NW style home is 3200+ sq ft with 3 level...
# 4  [Perfect for groups. 2 bedrooms, full bathroom...
#
#                                 descricao_vizinhanca  \
# 0  [Lower Queen Anne is near the Seattle Center (...
# 1  [--, Capital Hill is the heart of Seattle, bor...
# 2  [Upper Queen Anne is a charming neighborhood f...
# 3  [The Views from our top floor!  Wallingford ha...
# 4  [Safeway grocery store within walking distance...
#
# ...

# %%
# Retornando as colunas para comparar qual as colunas que estão em lista
colunas = list(dados_hospedagem.columns)
colunas
# Out:
# ['avaliacao_geral',
#  'experiencia_local',
#  'max_hospedes',
#  'descricao_local',
#  'descricao_vizinhanca',
#  'quantidade_banheiros',
#  'quantidade_quartos',
#  'quantidade_camas',
#  'modelo_cama',
#  'comodidades',
#  'taxa_deposito',
#  'taxa_limpeza',
#  'preco']

# %%
# Usando o explode para remover as lista das colunas 
dados_hospedagem = dados_hospedagem.explode(colunas[3:])

# %%
# Visualizando
dados_hospedagem.head()
# Out:
#   avaliacao_geral experiencia_local max_hospedes  \
# 0            10.0                --            1
# 0            10.0                --            1
# 0            10.0                --            1
# 0            10.0                --            1
# 0            10.0                --            1
#
#                                      descricao_local  \
# 0  This clean and comfortable one bedroom sits ri...
# 0  Our century old Upper Queen Anne house is loca...
# 0  Cozy room in two-bedroom apartment along the l...
# 0  Very lovely and cozy room for one. Convenientl...
# 0  The “Studio at Mibbett Hollow' is in a Beautif...
#
#                                 descricao_vizinhanca quantidade_banheiros  \
# 0  Lower Queen Anne is near the Seattle Center (s...                    1
# 0  Upper Queen Anne is a really pleasant, unique ...                    1
# 0  The convenience of being in Seattle but on the...                    1
# ...

# %%
# Necessário resetar o index
dados_hospedagem.reset_index(inplace=True, drop=True)

# %%
# Visualizando
dados_hospedagem.head()
# Out:
#   avaliacao_geral experiencia_local max_hospedes  \
# 0            10.0                --            1
# 1            10.0                --            1
# 2            10.0                --            1
# 3            10.0                --            1
# 4            10.0                --            1
#
#                                      descricao_local  \
# 0  This clean and comfortable one bedroom sits ri...
# 1  Our century old Upper Queen Anne house is loca...
# 2  Cozy room in two-bedroom apartment along the l...
# 3  Very lovely and cozy room for one. Convenientl...
# 4  The “Studio at Mibbett Hollow' is in a Beautif...
#
#                                 descricao_vizinhanca quantidade_banheiros  \
# 0  Lower Queen Anne is near the Seattle Center (s...                    1
# 1  Upper Queen Anne is a really pleasant, unique ...                    1
# 2  The convenience of being in Seattle but on the...                    1
# ...

# %%
# Verificando as informações dos dados - todos os dados estão como object necessário tratar valores
dados_hospedagem.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3818 entries, 0 to 3817
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   avaliacao_geral       3818 non-null   object
#  1   experiencia_local     3818 non-null   object
#  2   max_hospedes          3818 non-null   object
#  3   descricao_local       3818 non-null   object
#  4   descricao_vizinhanca  3818 non-null   object
#  5   quantidade_banheiros  3818 non-null   object
#  6   quantidade_quartos    3818 non-null   object
#  7   quantidade_camas      3818 non-null   object
#  8   modelo_cama           3818 non-null   object
#  9   comodidades           3818 non-null   object
#  10  taxa_deposito         3818 non-null   object
#  11  taxa_limpeza          3818 non-null   object
#  12  preco                 3818 non-null   object
# dtypes: object(13)
# memory usage: 387.9+ KB

# %%
# Lista de colunas para alteração de tipo
col_alterar = ['max_hospedes','quantidade_banheiros','quantidade_quartos','quantidade_camas']
col_regex = ['taxa_deposito','taxa_limpeza','preco']

# %%
# Convertendo os valores numericos com o astype
dados_hospedagem[col_alterar] = dados_hospedagem[col_alterar].astype(int)
dados_hospedagem['avaliacao_geral'] = dados_hospedagem['avaliacao_geral'].astype(float)

# As colunas taxa_deposito, taxa_limpeza, preco tem um digito '$' sendo necessário um regex para a retirada
dados_hospedagem[col_regex] = (dados_hospedagem[col_regex].replace(r'[^\d.]', '', regex=True).astype(float).astype(int))

# %%
# Visualizando as informações
dados_hospedagem.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3818 entries, 0 to 3817
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   avaliacao_geral       3162 non-null   float64
#  1   experiencia_local     3818 non-null   object
#  2   max_hospedes          3818 non-null   int64
#  3   descricao_local       3818 non-null   object
#  4   descricao_vizinhanca  3818 non-null   object
#  5   quantidade_banheiros  3818 non-null   int64
#  6   quantidade_quartos    3818 non-null   int64
#  7   quantidade_camas      3818 non-null   int64
#  8   modelo_cama           3818 non-null   object
#  9   comodidades           3818 non-null   object
#  10  taxa_deposito         3818 non-null   int64
#  11  taxa_limpeza          3818 non-null   int64
#  12  preco                 3818 non-null   int64
# dtypes: float64(1), int64(7), object(5)
# memory usage: 387.9+ KB

# %%
# Visualizando dataframe
dados_hospedagem.head()
# Out:
#    avaliacao_geral experiencia_local  max_hospedes  \
# 0             10.0                --             1
# 1             10.0                --             1
# 2             10.0                --             1
# 3             10.0                --             1
# 4             10.0                --             1
#
#                                      descricao_local  \
# 0  This clean and comfortable one bedroom sits ri...
# 1  Our century old Upper Queen Anne house is loca...
# 2  Cozy room in two-bedroom apartment along the l...
# 3  Very lovely and cozy room for one. Convenientl...
# 4  The “Studio at Mibbett Hollow' is in a Beautif...
#
#                                 descricao_vizinhanca  quantidade_banheiros  \
# 0  Lower Queen Anne is near the Seattle Center (s...                     1
# 1  Upper Queen Anne is a really pleasant, unique ...                     1
# 2  The convenience of being in Seattle but on the...                     1
# ...

# %% [markdown]
# #### Trabalhando com as colunas de texto

# %%
# Colocando os textos em minusculos
dados_hospedagem['descricao_local'] = dados_hospedagem['descricao_local'].str.lower()

# Alterando a coluna com regex para remover todos os caracteres alem do texto, ifen e a apostases
dados_hospedagem['descricao_local'] = dados_hospedagem['descricao_local'].str.replace(r'[^a-zA-Z0-9\-\']', ' ', regex=True)

# Agora esse regex irá verificar se há texto antes e depois do ifen senao ele remove
dados_hospedagem['descricao_local'] = dados_hospedagem['descricao_local'].str.replace(r'(?<!\w)-(?!\w)', '', regex=True)

# %%
# Criar tokenizaçãoa partir do texto com o split
dados_hospedagem['descricao_local'] = dados_hospedagem['descricao_local'].str.split(' ')

# %%
# Agora o tratamento será na coluna comodidades para gerar a tokenização nela
dados_hospedagem['comodidades'] = dados_hospedagem['comodidades'].str.replace(r'\{|}|\"','',regex=True)
dados_hospedagem['comodidades'] = dados_hospedagem['comodidades'].str.split(',')

# %%
# Trabalhando a coluna descricao_vizinhanca
dados_hospedagem['descricao_vizinhanca'] = dados_hospedagem['descricao_vizinhanca'].str.replace(r'[^a-zA-Z0-9\-\']', ' ', regex=True)
dados_hospedagem['descricao_vizinhanca'] = dados_hospedagem['descricao_vizinhanca'].str.replace(r'(?<!\w)-(?!\w)', '', regex=True)

# %%
# Criar tokenizaçãoa partir do texto com o split
dados_hospedagem['descricao_vizinhanca'] = dados_hospedagem['descricao_vizinhanca'].str.split(' ')

# %%
# Visualizando dataframe
dados_hospedagem.head()
# Out:
#    avaliacao_geral experiencia_local  max_hospedes  \
# 0             10.0                --             1
# 1             10.0                --             1
# 2             10.0                --             1
# 3             10.0                --             1
# 4             10.0                --             1
#
#                                      descricao_local  \
# 0  [this, clean, and, comfortable, one, bedroom, ...
# 1  [our, century, old, upper, queen, anne, house,...
# 2  [cozy, room, in, two-bedroom, apartment, along...
# 3  [very, lovely, and, cozy, room, for, one, , co...
# 4  [the, , studio, at, mibbett, hollow', is, in, ...
#
#                                 descricao_vizinhanca  quantidade_banheiros  \
# 0  [Lower, Queen, Anne, is, near, the, Seattle, C...                     1
# 1  [Upper, Queen, Anne, is, a, really, pleasant, ...                     1
# 2  [The, convenience, of, being, in, Seattle, but...                     1
# ...

# %% [markdown]
# ### Trabalhando com os moveis disponiveis

# %%
# Carregando os dados
dados_moveis = pd.read_json('moveis_disponiveis.json')
dados_moveis
# Out:
#           id        data  vaga_disponivel    preco
# 0        857  2016-01-04            False     None
# 1        857  2016-01-05            False     None
# 2        857  2016-01-06            False     None
# 3        857  2016-01-07            False     None
# 4        857  2016-01-08            False     None
# ...      ...         ...              ...      ...
# 364995  3279  2016-12-29             True  $140.00
# 364996  3279  2016-12-30             True  $140.00
# 364997  3279  2016-12-31             True  $140.00
# 364998  3279  2017-01-01             True  $140.00
# 364999  3279  2017-01-02            False     None
#
# [365000 rows x 4 columns]

# %%
# Precisando usar a coluna de data percebo que não esta no formato de data, sendo necessário alterar
dados_moveis.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 365000 entries, 0 to 364999
# Data columns (total 4 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   id               365000 non-null  int64
#  1   data             365000 non-null  object
#  2   vaga_disponivel  365000 non-null  bool
#  3   preco            270547 non-null  object
# dtypes: bool(1), int64(1), object(2)
# memory usage: 11.5+ MB

# %%
# Usando a função do pandas datetime para alterar a coluna
dados_moveis['data'] = pd.to_datetime(dados_moveis['data'])

# %%
# Verificando alteração na data
dados_moveis.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 365000 entries, 0 to 364999
# Data columns (total 4 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   id               365000 non-null  int64
#  1   data             365000 non-null  datetime64[ns]
#  2   vaga_disponivel  365000 non-null  bool
#  3   preco            270547 non-null  object
# dtypes: bool(1), datetime64[ns](1), int64(1), object(1)
# memory usage: 11.5+ MB

# %%
# Usando a função strftime para gerar uma valor de data por mes e ano
dados_moveis['data'].dt.strftime('%Y-%m')
# Out:
# 0         2016-01
# 1         2016-01
# 2         2016-01
# 3         2016-01
# 4         2016-01
#            ...
# 364995    2016-12
# 364996    2016-12
# 364997    2016-12
# 364998    2017-01
# 364999    2017-01
# Name: data, Length: 365000, dtype: object

# %%
# Agora é preciso criar uma contagem de vagas por mês, para sabermos as vagas pela demanda de solicitações de aluguel
# Agrupando os valores por mês para criar um subset
subset = dados_moveis.groupby(dados_moveis['data'].dt.strftime('%Y-%m'))['vaga_disponivel'].sum()
subset
# Out:
# data
# 2016-01    16543
# 2016-02    20128
# 2016-03    23357
# 2016-04    22597
# 2016-05    23842
# 2016-06    23651
# 2016-07    22329
# 2016-08    22529
# 2016-09    22471
# 2016-10    23765
# 2016-11    23352
# 2016-12    24409
# 2017-01     1574
# Name: vaga_disponivel, dtype: int64

# %%
# Verificado valores nulos
dados_moveis['preco'].isnull().sum()
# Out:
# np.int64(94453)

# %%
# Tratando valores nulos na coluna preço 
dados_moveis['preco'] = dados_moveis['preco'].fillna('0.0')

# %%
# Visualizando
dados_moveis
# Out:
#           id       data  vaga_disponivel    preco
# 0        857 2016-01-04            False      0.0
# 1        857 2016-01-05            False      0.0
# 2        857 2016-01-06            False      0.0
# 3        857 2016-01-07            False      0.0
# 4        857 2016-01-08            False      0.0
# ...      ...        ...              ...      ...
# 364995  3279 2016-12-29             True  $140.00
# 364996  3279 2016-12-30             True  $140.00
# 364997  3279 2016-12-31             True  $140.00
# 364998  3279 2017-01-01             True  $140.00
# 364999  3279 2017-01-02            False      0.0
#
# [365000 rows x 4 columns]

# %%
# Usando 
dados_moveis['preco'] = dados_moveis['preco'].replace(r'[^\d.]', '', regex=True).astype(float)

# %%
# Visualizando
dados_moveis
# Out:
#           id       data  vaga_disponivel  preco
# 0        857 2016-01-04            False    0.0
# 1        857 2016-01-05            False    0.0
# 2        857 2016-01-06            False    0.0
# 3        857 2016-01-07            False    0.0
# 4        857 2016-01-08            False    0.0
# ...      ...        ...              ...    ...
# 364995  3279 2016-12-29             True  140.0
# 364996  3279 2016-12-30             True  140.0
# 364997  3279 2016-12-31             True  140.0
# 364998  3279 2017-01-01             True  140.0
# 364999  3279 2017-01-02            False    0.0
#
# [365000 rows x 4 columns]
